# %% [markdown]
# <a href="https://colab.research.google.com/github/IsraelOsagbe/DataLab/blob/main/LabData1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Combined.xlsx')
df.head()
# Out:
#    Pressure A  Delta P  Delta_P(Mpa)    Q _avg       Q(m3/s)  aperture(m)  \
# 0      1044.0      5.0  34353.741497  0.737944  1.229906e-08     0.000020
# 1      1044.0      5.0  34353.741497  0.822516  1.370861e-08     0.000021
# 2      1044.0      5.0  34353.741497  0.729762  1.216270e-08     0.000020
# 3      1044.0      5.0  34353.741497  0.648805  1.081341e-08     0.000019
# 4      1044.0      5.0  34353.741497  0.584114  9.735233e-09     0.000018
#
#          k (m2)        k [mD]          T []  Pressure A.1  ...       T [].15  \
# 0  3.270905e-11  32709.054306  3.630352e-14        1160.0  ...  1.345506e-14
# 1  3.516271e-11  35162.708950  3.902681e-14        1160.0  ...  1.131750e-14
# 2  3.246684e-11  32466.844189  3.603469e-14        1160.0  ...  1.533839e-14
# 3  3.001893e-11  30018.925913  3.331777e-14        1160.0  ...  1.574379e-14
# 4  2.798880e-11  27988.802895  3.106455e-14        1160.0  ...  1.554172e-14
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Pressure A  Delta P  Delta_P(Mpa)    Q _avg       Q(m3/s)  aperture(m)  \
# 0         1044.0      5.0  34353.741497  0.737944  1.229906e-08     0.000020
# 1         1044.0      5.0  34353.741497  0.822516  1.370861e-08     0.000021
# 2         1044.0      5.0  34353.741497  0.729762  1.216270e-08     0.000020
# 3         1044.0      5.0  34353.741497  0.648805  1.081341e-08     0.000019
# 4         1044.0      5.0  34353.741497  0.584114  9.735233e-09     0.000018
# ...          ...      ...           ...       ...           ...          ...
# 2103         NaN      NaN           NaN       NaN           NaN          NaN
# 2104         NaN      NaN           NaN       NaN           NaN          NaN
# 2105         NaN      NaN           NaN       NaN           NaN          NaN
# 2106         NaN      NaN           NaN       NaN           NaN          NaN
# 2107         NaN      NaN           NaN       NaN           NaN          NaN
#
# ...

# %%
data = {
    '001_1044_1305':df.iloc[0:1597, 0:9],
    '002_1160_1450':df.iloc[0:1612, 9:18],
    '003_1329_1740':df.iloc[0:1551, 18:27],
    '004_1740_2175':df.iloc[0:1665, 27:36],
    '005_1965_2456':df.iloc[0:1614, 36:45],
    '006_1740_2175':df.iloc[0:1692, 45:54],
    '007_1329_1740':df.iloc[0:2110, 54:63],
    '008_1160_1450':df.iloc[0:1569, 63:72],
    '009_1044_1305':df.iloc[0:1606, 72:81],
    '010_1160_1450':df.iloc[0:1644, 81:90],
    '011_1329_1740':df.iloc[0:1555, 90:99],
    '012_1740_2175':df.iloc[0:1478, 99:108],
    '013_1965_2456':df.iloc[0:1537, 108:117],
    '014_1740_2175':df.iloc[0:1521, 117:126],
    '015_1329_1740':df.iloc[0:1607, 126:135],
    '016_1160_1450':df.iloc[0:1098, 135:144],
    '017_1044_1305':df.iloc[0:1085, 144:153]    
}


# def drop_nans_from_dict(d):
#   cleaned_data = {}
#   for keys in d.items():
#     cleaned_values = [item for item in d[keys] if not np.isnan(item)]
#     cleaned_data[keys] = cleaned_values

#   return cleaned_data

# drop_nans_from_dict(data)

# %%
test1 = data['001_1044_1305']
test2 = data['002_1160_1450']
test3 = data['003_1329_1740']
test4 =  data['004_1740_2175']
test5 = data['005_1965_2456']
test6 = data['006_1740_2175']
test7 = data['007_1329_1740']
test8 = data['008_1160_1450']
test9 = data['009_1044_1305']
test10 = data['010_1160_1450']
test11, test12, test13, test14, test15, test16, test17 = data['011_1329_1740'], data['012_1740_2175'], data['013_1965_2456'], data['014_1740_2175'], data['015_1329_1740'], data['016_1160_1450'], data['017_1044_1305']



plt.figure(figsize=(10,10))
# fig, ax = plt.subplots()
plt.plot(test1.loc[0:580, ['k [mD]']], test1.loc[0:580, ['Q(m3/s)']], 'b')
plt.plot(test1.loc[592:945, ['k [mD]']], test1.loc[592:945, ['Q(m3/s)']], 'r')
plt.plot(test1.loc[955:1280, ['k [mD]']], test1.loc[955:1280, ['Q(m3/s)']], 'k')
plt.plot(test1.loc[1292:1595, ['k [mD]']], test1.loc[1292:1595, ['Q(m3/s)']], 'g')
plt.show()


# plt.plot(test2.loc[0:695, ['k [mD].1']], test2.loc[0:695, ['Q(m3/s).1']], 'r')
# plt.plot(test3.loc[0:620, ['k [mD].2']], test3.loc[0:620, ['Q(m3/s).2']], 'g')
# plt.plot(test4.loc[0:620, ['k [mD].3']], test4.loc[0:620, ['Q(m3/s).3']], 'k')
# handles, labels = ax.get_legend_handles_labels()
# ax.legend(handles, labels)

# %%
test4
# Out:
#       Pressure A.3  Delta P.3  Delta_P(Mpa).3  Q _avg.3     Q(m3/s).3  \
# 0           1740.0        2.0      13741.4966  0.058411  9.740000e-10
# 1           1740.0        2.0      13741.4966  0.161059  2.680000e-09
# 2           1740.0        2.0      13741.4966  0.054891  9.150000e-10
# 3           1740.0        2.0      13741.4966  0.082955  1.380000e-09
# 4           1740.0        2.0      13741.4966  0.058506  9.750000e-10
# ...            ...        ...             ...       ...           ...
# 1660        1740.0       20.0     137414.9660  0.589252  9.820000e-09
# 1661        1740.0       20.0     137414.9660  0.680388  1.130000e-08
# 1662        1740.0       20.0     137414.9660  0.791408  1.320000e-08
# 1663           NaN        NaN             NaN       NaN           NaN
# 1664           NaN        NaN             NaN       NaN           NaN
#
#       aperture(m).3      k (m2).3  k [mD].3        T [].3
# 0          0.000012  1.110000e-11   11100.0  1.230000e-14
# ...
